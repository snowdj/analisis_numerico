# %%
using TestImages, Images
img = testimage("lake")
# Out:
# 512×512 Array{GrayA{N0f8},2}:
#  GrayA{N0f8}(0.145,1.0)  GrayA{N0f8}(0.502,1.0)  …  GrayA{N0f8}(0.588,1.0)
#  GrayA{N0f8}(0.141,1.0)  GrayA{N0f8}(0.478,1.0)     GrayA{N0f8}(0.49,1.0)
#  GrayA{N0f8}(0.145,1.0)  GrayA{N0f8}(0.396,1.0)     GrayA{N0f8}(0.357,1.0)
#  GrayA{N0f8}(0.145,1.0)  GrayA{N0f8}(0.439,1.0)     GrayA{N0f8}(0.333,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.392,1.0)     GrayA{N0f8}(0.271,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.427,1.0)  …  GrayA{N0f8}(0.282,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.455,1.0)     GrayA{N0f8}(0.31,1.0)
#  GrayA{N0f8}(0.129,1.0)  GrayA{N0f8}(0.537,1.0)     GrayA{N0f8}(0.275,1.0)
#  GrayA{N0f8}(0.086,1.0)  GrayA{N0f8}(0.62,1.0)      GrayA{N0f8}(0.384,1.0)
#  GrayA{N0f8}(0.078,1.0)  GrayA{N0f8}(0.494,1.0)     GrayA{N0f8}(0.38,1.0)
#  GrayA{N0f8}(0.071,1.0)  GrayA{N0f8}(0.416,1.0)  …  GrayA{N0f8}(0.349,1.0)
#  GrayA{N0f8}(0.063,1.0)  GrayA{N0f8}(0.373,1.0)     GrayA{N0f8}(0.471,1.0)
# ...

# %%
p=0.05;
noise=zeros(512*512);
for i=1:512*512
    aux = rand()
    if(aux<p)
        img[i]=0;
    end
end
img
# Out:
# 512×512 Array{GrayA{N0f8},2}:
#  GrayA{N0f8}(0.0,1.0)    GrayA{N0f8}(0.502,1.0)  …  GrayA{N0f8}(0.588,1.0)
#  GrayA{N0f8}(0.141,1.0)  GrayA{N0f8}(0.478,1.0)     GrayA{N0f8}(0.49,1.0)
#  GrayA{N0f8}(0.145,1.0)  GrayA{N0f8}(0.396,1.0)     GrayA{N0f8}(0.357,1.0)
#  GrayA{N0f8}(0.145,1.0)  GrayA{N0f8}(0.439,1.0)     GrayA{N0f8}(0.333,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.392,1.0)     GrayA{N0f8}(0.271,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.0,1.0)    …  GrayA{N0f8}(0.282,1.0)
#  GrayA{N0f8}(0.133,1.0)  GrayA{N0f8}(0.455,1.0)     GrayA{N0f8}(0.31,1.0)
#  GrayA{N0f8}(0.129,1.0)  GrayA{N0f8}(0.0,1.0)       GrayA{N0f8}(0.275,1.0)
#  GrayA{N0f8}(0.086,1.0)  GrayA{N0f8}(0.62,1.0)      GrayA{N0f8}(0.384,1.0)
#  GrayA{N0f8}(0.078,1.0)  GrayA{N0f8}(0.494,1.0)     GrayA{N0f8}(0.38,1.0)
#  GrayA{N0f8}(0.071,1.0)  GrayA{N0f8}(0.416,1.0)  …  GrayA{N0f8}(0.349,1.0)
#  GrayA{N0f8}(0.063,1.0)  GrayA{N0f8}(0.373,1.0)     GrayA{N0f8}(0.471,1.0)
# ...
