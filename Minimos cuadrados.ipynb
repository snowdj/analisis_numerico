# %%
using Polynomials, Distributions, PyPlot

x=collect(1:.5:10);
y=2x+1+rand(Normal(),length(x))
# Out:
# 19-element Array{Float64,1}:
#   2.18561
#   4.97829
#   6.90439
#   6.49132
#   5.66291
#   7.99253
#   8.8305
#  10.8116
#   8.37572
#  11.6279
#  13.5607
#  14.5749
#  16.0534
#  15.52
#  16.2629
#  18.7187
#  19.4902
#  19.8323
#  22.7943

# %%
plot(x,y,"*");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f475003ed10>)

# %%
p=polyfit(x,y,1)
# Out:
# Poly(0.8844233622191254 + 2.0465463867649527*x)

# %%
plot(x,polyval(p,x))
plot(x,y,"*")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f475018a390>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4750230f90>

# %%
p=polyfit(x,y,2)
# Out:
# Poly(1.9837631276448398 + 1.5149974891964744*x + 0.04832262705167987*x^2)

# %%
plot(x,polyval(p,x))
plot(x,y,"*");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f47502bab90>)
