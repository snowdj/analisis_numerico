# %% [markdown]
# ## Metodo de Newton para raices

# %%
using PyPlot

#defino la función a utilizar

function f(x,a)
    return x.^2-a, 2*x;
end
# Out:
# f (generic function with 1 method)

# %%
a=2;
xx=(0:.01:2*a)

plot(xx,f(xx,a)[1])
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fccb27f72d0>)

# %%
x=4.0;
paso=Inf;

plot(xx,f(xx,a)[1])
grid()

while (abs(paso)/abs(x))>1e-10
    
    fx,dfx = f(x,a)
    plot(x,fx,"*")
    plot(xx,fx+(xx-x)*dfx,":")
    paso = -fx/dfx;
    x=x+paso;
    println(x)
end
plot(x,f(x,a)[1],"*");
# Out:
# 2.
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fccb258e090>)
# 25
# 1.5694444444444444
# 1.4218903638151426
# 1.4142342859400734
# 1.4142135625249321
# 1.4142135623730951
# 1.414213562373095
